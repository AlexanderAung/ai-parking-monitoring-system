# %%
import pandas as pd
from pathlib import Path

current_dir = Path.cwd()
project_root = current_dir.parent 

print("Project Root:", project_root)
issues_csv_path = project_root/"src"/"data"/"audit_report"/"issues.csv"
# Out:
# Project Root: /Users/boy/Desktop/ai-parking-monitoring-system

# %%
df = pd.read_csv(issues_csv_path)

# %%
df.head()
# Out:
#                                                 file     check severity  \
# 0  ../../data/raw/train/02f6b0600b3ad4ed_jpg.rf.4...  box_tiny     WARN
# 1  ../../data/raw/train/02f6b0600b3ad4ed_jpg.rf.4...  box_tiny     WARN
# 2  ../../data/raw/train/02f6b0600b3ad4ed_jpg.rf.4...  box_tiny     WARN
# 3  ../../data/raw/train/02f6b0600b3ad4ed_jpg.rf.4...  box_tiny     WARN
# 4  ../../data/raw/train/02f6b0600b3ad4ed_jpg.rf.4...  box_tiny     WARN
#
#                         detail
# 0  rel_area=4.25e-04 (17x14px)
# 1   rel_area=2.29e-04 (16x8px)
# 2   rel_area=1.29e-04 (12x6px)
# 3  rel_area=2.68e-04 (15x10px)
# 4  rel_area=3.40e-04 (19x10px)
